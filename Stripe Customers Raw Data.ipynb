# %%
df = spark.read.option("recursiveFileLookup", "true").parquet("abfss://keywrds-stripe-data@keywrdsstripedata.dfs.core.windows.net/2025*/livemode/customers/")
# df.printSchema()

# %%
df.write.saveAsTable("stripe.raw_stripe_data.tbl__stripe__initial_raw_customers_data")

# %%
# %sql 
# select * from `stripe`.raw_stripe_data.tbl__stripe__initial_raw_customers_data limit 100
